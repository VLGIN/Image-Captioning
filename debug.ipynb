# %%
import csv
import sys
csv.field_size_limit(sys.maxsize)
# Out:
# 131072

# %%
from google.colab import drive
drive.mount("/content/drive")

import os
os.chdir("/content/drive/MyDrive/PROJECT_3/")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import csv
import sys

# %%
csv.field_size_limit(sys.maxsize)
# Out:
# 131072

# %%
f = open("scene_graph_benchmark/output/X152C5_test/inference/vinvl_vg_x152c4/predictions.tsv")

# %%
tsv_reader = csv.reader(f, delimiter="\t")

# %%
for row in tsv_reader:
  print(row)
  break
# Out:
# ['VizWiz_train_00009470', '{"objects": [{"rect": [500.110107421875, 940.916259765625, 559.1435546875, 1041.5123291015625], "bbox_id": 0, "class": "letter", "conf": 0.7309833765029907, "feature": "..."}, {"rect": [220.04248046875, 691.8413696289062, 282.817138671875, 823.7597045898438], "bbox_id": 1, "class": "letter", "conf": 0.6445903778076172, "feature": "..."}, {"rect": [151.16317749023438, 771.0067749023438, 753.6521606445312, 1152.2296142578125], "bbox_id": 2, "class": "label", "conf": 0.6135207414627075, "feature": "..."}, {"rect": [132.8936004638672, 268.8334655761719, 770.3679809570312, 1294.3861083984375], "bbox_id": 3, "class": "can", "conf": 0.6059163212776184, "feature": "..."}, {"rect": [560.5339965820312, 103.47745513916016, 966.3866577148438, 1092.1541748046875], "bbox_id": 4, "class": "bag", "conf": 0.4920637309551239, "feature": "..."}, {"rect": [550.2208862304688, 706.3402099609375, 664.7550048828125, 849.077392578125], "bbox_id": 5, "class": "letter", "conf": 0.3961144983768463, "feature": "..."}, {"rect": [222.18270874023438, 920.112548828125, 274.1766662597656, 1008.7577514648438], "bbox_id": 6, "class": "letter", "conf": 0.3811679780483246, "feature": "..."}, {"rect": [560.646240234375, 935.533447265625, 586.6261596679688, 1040.1356201171875], "bbox_id": 7, "class": "letter", "conf": 0.3679032623767853, "feature": "..."}, {"rect": [445.695556640625, 702.0875854492188, 554.4437866210938, 830.353759765625], "bbox_id": 8, "class": "letter", "conf": 0.35246288776397705, "feature": "..."}, {"rect": [432.0096740722656, 966.4312133789062, 485.1668701171875, 1034.2928466796875], "bbox_id": 9, "class": "letter", "conf": 0.33581143617630005, "feature": "..."}, {"rect": [300.336181640625, 702.1998901367188, 380.51080322265625, 831.1650390625], "bbox_id": 10, "class": "letter", "conf": 0.33092617988586426, "feature": "..."}, {"rect": [260.0968933105469, 785.1578979492188, 762.4738159179688, 1293.562255859375], "bbox_id": 11, "class": "drink", "conf": 0.3172856271266937, "feature": "..."}, {"rect": [579.7317504882812, 943.153076171875, 640.27587890625, 1045.12548828125], "bbox_id": 12, "class": "letter", "conf": 0.2581169605255127, "feature": "..."}, {"rect": [0.0, 35.96333312988281, 464.9488525390625, 1111.3685302734375], "bbox_id": 13, "class": "board", "conf": 0.2552860975265503, "feature": "..."}, {"rect": [265.6754150390625, 676.886962890625, 686.659423828125, 848.0572509765625], "bbox_id": 14, "class": "letter", "conf": 0.242207333445549, "feature": "..."}, {"rect": [748.5532836914062, 611.1791381835938, 933.3597412109375, 1294.3861083984375], "bbox_id": 15, "class": "plastic", "conf": 0.20948034524917603, "feature": "..."}, {"rect": [251.39732360839844, 936.674560546875, 648.5191650390625, 1107.6187744140625], "bbox_id": 16, "class": "word", "conf": 0.20580290257930756, "feature": "..."}, {"rect": [0.0, 16.14312171936035, 929.5172119140625, 1237.092529296875], "bbox_id": 17, "class": "box", "conf": 0.20257794857025146, "feature": "..."}, {"rect": [338.90423583984375, 1053.2694091796875, 496.4796447753906, 1134.6923828125], "bbox_id": 18, "class": "word", "conf": 0.2005094289779663, "feature": "..."}], "relations": null}']
